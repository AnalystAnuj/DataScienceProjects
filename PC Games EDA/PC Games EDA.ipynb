# %% [markdown]
# # Overview

# %% [markdown]
# In this notebook, our focus will be on conducting exploratory data analysis for computer games. A comprehensive explanation of the dataset headings and the specific data we are delving into is provided below. Furthermore, there is room for expanding and enriching this study by incorporating diverse graphical representations and exploring additional datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("computer_games.csv")

# %%
df
# Out:
#                                     Name                        Developer  \
# 0                                A-Men 2                     Bloober Team
# 1                                A-Train                          Artdink
# 2                             A-10 Cuba!              Parsoft Interactive
# 3                              A.D. 2044                  R.M.P. Software
# 4     A.D.A.M. Life's Greatest Mysteries  Columbia Healthcare Corporation
# ...                                  ...                              ...
# 1090                688(I) Hunter/Killer                   Sonalysts Inc.
# 1091                            7 Colors                       Gamos Ltd.
# 1092                                7554                      Emobi Games
# 1093                          7th Legion           Vision, Epic MegaGames
# 1094                  9: The Last Resort              Tribeca Interactive
#
#                              Producer                    Genre  \
# ...

# %%
df.shape
# Out:
# (1095, 6)

# %%
df.isnull().sum()
# Out:
# Name                0
# Developer           0
# Producer            0
# Genre               0
# Operating System    0
# Date Released       0
# dtype: int64

# %%
df.describe()
# Out:
#                  Name Developer         Producer                 Genre  \
# count            1095      1095             1095                  1095
# unique           1094       583              489                   282
# top     A Hat in Time     Maxis  Electronic Arts  First-person shooter
# freq                2        30               84                   103
#
#          Operating System Date Released
# count                1095          1095
# unique                 83           915
# top     Microsoft Windows          1995
# freq                  600             9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              1095 non-null   object
#  1   Developer         1095 non-null   object
#  2   Producer          1095 non-null   object
#  3   Genre             1095 non-null   object
#  4   Operating System  1095 non-null   object
#  5   Date Released     1095 non-null   object
# dtypes: object(6)
# memory usage: 51.5+ KB

# %%
Top_10_Developers= df['Developer'].value_counts().head(10)
Top_10_Developers
# Out:
# Developer
# Maxis                          30
# Valve                          20
# Square Enix                    18
# Blizzard Entertainment         18
# Ubisoft Montreal               17
# Quiet River                    12
# BioWare                        11
# Strategic Simulations, Inc.    11
# Data Design Interactive        10
# TalonSoft                      10
# Name: count, dtype: int64

# %%
#top 10 game developing companies
plt.style.use("ggplot")
plt.figure(figsize=(15,10))
Top_10_Developers.plot(kind="barh",color="#1F8BC1",title="Top 10 Computer Games Developing Companies")
plt.show()

# %% [markdown]
# From above graph
# 1. Maxis is leading developer and
# 2. TalonSoft is least developer

# %%
#Now let's analyze the top 10 producing companies.
Top_10_producers = df['Producer'].value_counts().head(10)
Top_10_producers
# Out:
# Producer
# Electronic Arts           84
# Ubisoft                   44
# Square Enix               31
# Eidos Interactive         28
# Paradox Interactive       22
# Valve                     20
# Blizzard Entertainment    19
# Microsoft Game Studios    18
# Bethesda Softworks        15
# Activision                14
# Name: count, dtype: int64

# %%
#top 10 game producing companies
plt.style.use("bmh")
plt.figure(figsize=(15,10))
Top_10_producers.plot(kind="barh",color="#1FC1B7",title="Top 10 Computer Games Producing Companies")
plt.show()

# %% [markdown]
# As can be seen from the graph, Electronic Arts company leads the list.

# %%
# Now let's take a look at the game types
Top_10_game_genres =df["Genre"].value_counts().head(10)
Top_10_game_genres
# Out:
# Genre
# First-person shooter    103
# RTS                      48
# Action-adventure         42
# Sports                   34
# Role-playing             33
# RPG                      30
# Action role-playing      29
# Life simulation          27
# Adventure                23
# Turn-based strategy      22
# Name: count, dtype: int64

# %%
# Top 10 Computer Game Genres
plt.style.use("bmh")
plt.figure(figsize=(15,10))
Top_10_game_genres.plot(kind="barh",color="#E8051F",title="Top 10 Computer Game Genres")
plt.show()

# %% [markdown]
# As can be seen from the graphic, 103 games are in the FPS type. Fps genre game is followed by RTS(48) AND Action-adventure (42) game genres.

# %%
#Let's take a look at operating systems.
OS_of_Games = df["Operating System"].value_counts().head(10)
OS_of_Games
# Out:
# Operating System
# Microsoft Windows                  600
# Microsoft Windows, macOS           191
# Microsoft Windows, Linux, macOS    141
# MS-DOS                              27
# Microsoft Windows, Linux            15
# Microsoft Windows, Mac OS X          7
# Microsoft Windows,                   6
# MS-DOS, Microsoft Windows            5
# DOS                                  5
# Microsoft Windows, OS X, Linux       5
# Name: count, dtype: int64

# %%
# Top 10 Computer Game Operating System
plt.style.use("bmh")
plt.figure(figsize=(15,10))
OS_of_Games.plot(kind="barh",color="#F55347",title="Top 10 Computer Game Operating System")
plt.show()

# %% [markdown]
# As can be seen from the graph, the Microsoft Windows operating system is at the top of the list.
